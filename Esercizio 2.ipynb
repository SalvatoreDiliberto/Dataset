# %%
import pandas as pd
import numpy as np

df = pd.read_csv('C:/Users/infob/Desktop/python/nuovo.py/Pandas/Esercizi develhope/World_Alcohol_Dataset - MAIN (1).csv', na_values='?')

# %% [markdown]
# 1) Write a Pandas program to filter the records from the world alcohol consumption dataset where the beer servings are greater than 200 lt and the life expectancy is above 70 years.

# %%
# Visualizzo il dataframe e vedo che mi mancano delle righe

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 177 entries, 0 to 176
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   country          177 non-null    object
#  1   beer_servings    176 non-null    float64
#  2   spirit_servings  176 non-null    float64
#  3   wine_servings    176 non-null    float64
#  4   life_expentancy  177 non-null    float64
#  5   region           177 non-null    object
#  6   gdp_per_capita   177 non-null    int64
# dtypes: float64(4), int64(1), object(2)
# memory usage: 9.8+ KB

# %%
# Vado a verificre se ho valori nulli, ovviamente si perché nell'importare il csv ho inserito na_values 

df.isna().sum()
# Out:
# country            0
# beer_servings      1
# spirit_servings    1
# wine_servings      1
# life_expentancy    0
# region             0
# gdp_per_capita     0
# dtype: int64

# %%
# Essendo che ho valori nulli vado a vedere con quali valori sostituirli, essendo che la std ha
# un valore elevato allora li sostituisco con la mediana

df.describe()
# Out:
#        beer_servings  spirit_servings  wine_servings  life_expentancy  \
# count     176.000000       176.000000     176.000000       177.000000
# mean      107.403409        77.420455      49.056818        71.679096
# std       101.824060        85.625526      79.950536         8.170086
# min         0.000000         0.000000       0.000000        51.000000
# 25%        20.750000         4.000000       1.000000        65.700000
# 50%        76.500000        53.000000       8.000000        74.000000
# 75%       192.250000       122.500000      59.000000        77.000000
# max       376.000000       438.000000     370.000000        88.000000
#
#        gdp_per_capita
# count      177.000000
# mean      8641.242938
# std       9838.887919
# min        500.000000
# 25%       1700.000000
# 50%       4800.000000
# 75%      11400.000000
# max      55100.000000

# %%
# Sostituisco i valori nulli con la mediana, poichè la std è abbastanza alta e quindi 
# ho dispersione dei valori

df1 = df.fillna(round(df['beer_servings'].median(),2))
df1 = df.fillna(round(df['spirit_servings'].median(),2))
df1 = df.fillna(round(df['wine_servings'].median(),2))

# %%
# Adesso applico le condizioni, visualizzo tutto il df e li ordino in modo decrescente per beer_servings e life_expentancy 

df1[(df1['beer_servings']>200) & (df1['life_expentancy']> 70)].sort_values(by=(['beer_servings','life_expentancy']),ascending=[False,False])
# Out:
#             country  beer_servings  spirit_servings  wine_servings  \
# 43          Czechia          361.0            170.0          134.0
# 61          Germany          346.0            117.0          175.0
# 127          Poland          343.0            215.0           56.0
# 94        Lithuania          343.0            244.0           56.0
# 172       Venezuela          333.0            100.0            3.0
# 77          Ireland          313.0            118.0          165.0
# 130         Romania          297.0            122.0          167.0
# 15          Belgium          295.0             84.0          212.0
# 122          Panama          285.0            104.0           18.0
# 146           Spain          284.0            157.0          112.0
# 136          Serbia          283.0            131.0          127.0
# 89           Latvia          281.0            216.0           62.0
# 8           Austria          279.0             75.0          191.0
# ...
